# %% [markdown]
# # PROGRAM - 1

# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
driver = webdriver.Chrome(r'/Users/ankitraj1/chromedriver')
time.sleep(3)

# %%
url = "https://www.amazon.in/"
driver.get(url)

# %%
#locating the search bar
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys("mobiles")                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//span[@id="nav-search-submit-text"]')       # Locating search_button by xpath
search_button.click()    

time.sleep(2)

# %%
#creating the empty list
Title=[]
Ratings=[]
price=[]

# %%
for j in driver.find_elements_by_xpath('//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]'):
        Title.append(j.text)
for k in driver.find_elements_by_xpath('//div[@class="a-row a-size-small"]/span[2]/a/span'):
        Ratings.append(k.text)
for l in driver.find_elements_by_xpath('//span[@class="a-price-whole"]'):
        price.append(l.text)

# %%
Title
# Out:
# ['New Apple iPhone 12 Mini (128GB) - White',
#  'Mi 11X 5G Cosmic Black 6GB RAM 128GB ROM | SD 870 | DisplayMate A+ rated E4 AMOLED | NCEMI upto 12 Months |Extra INR 1,999 Off Through Coupons',
#  'Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor',
#  'Redmi 9A (Nature Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#  'Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)',
#  'Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate',
#  'Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128GB Storage)',
#  'Oppo A31 (Fantasy White, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Oppo A31 (Mystery Black, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storage) - 48MP Quad Camera & Full HD+ Display',
# ...

# %%
#creating the data frame for the outputs

data = list(zip(Title,Ratings,price))
df = pd.DataFrame (data,columns=['Title','Ratings','price'])

# %%
df.head(20)
# Out:
#                                                 Title  Ratings   price
# 0            New Apple iPhone 12 Mini (128GB) - White    3,505  21,999
# 1   Mi 11X 5G Cosmic Black 6GB RAM 128GB ROM | SD ...      421  21,999
# 2   Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 500...   37,828  23,999
# 3   Redmi 9A (Nature Green, 2GB RAM, 32GB Storage)...   42,463  62,999
# 4   Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB...  182,971  29,999
# 5   Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage...   13,288   8,799
# 6   Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128...   65,202   6,999
# 7   Oppo A31 (Fantasy White, 6GB RAM, 128GB Storag...   11,936  14,999
# 8   Oppo A31 (Mystery Black, 6GB RAM, 128GB Storag...   11,936  10,999
# 9   Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storag...   58,502  16,999
# 10  Samsung Galaxy A72 (Black, 8GB RAM, 128GB Stor...      118  10,990
# 11  Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage...   13,288  10,990
# ...

# %% [markdown]
# # PROGRAM -3

# %%
import os
import selenium
from selenium import webdriver
import time
from PIL import Image
import io
import requests
from selenium.common.exceptions import ElementClickInterceptedException

# %%
#Install driver
opts=webdriver.ChromeOptions()
opts.headless=True

driver = webdriver.Chrome(r'/Users/ankitraj1/chromedriver')

# %%
search_url = "https://www.google.com/search?q={q}&tbm=isch&tbs=sur%3Afc&hl=en&ved=0CAIQpwVqFwoTCKCa1c6s4-oCFQAAAAAdAAAAABAC&biw=1251&bih=568"
driver.get(search_url.format(q='fruits'))

# %%
def scroll_to_end(driver):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)#sleep_between_interactions

# %%
#Locate the images to be scraped from the current page 
imgResults = driver.find_elements_by_xpath("//img[contains(@class,'Q4LuWd')]")
totalResults=len(imgResults)

# %%
img_urls = set()
for i in  range(3,len(imgResults)):
    img=imgResults[i]
    try:
        img.click()
        time.sleep(2)
        actual_images = driver.find_elements_by_css_selector('img.n3VNCb')
        for actual_image in actual_images:
            if actual_image.get_attribute('src') and 'https' in actual_image.get_attribute('src'):
                img_urls.add(actual_image.get_attribute('src'))
    except ElementClickInterceptedException or ElementNotInteractableException as err:
        print(err)

# %%
img_urls
# Out:
# {'https://c0.wallpaperflare.com/preview/441/904/850/berries-bowl-of-fruit-citrus-citrus-fruits.jpg',
#  'https://c0.wallpaperflare.com/preview/923/294/410/bananas-fruit-delicious-sweet.jpg',
#  'https://cdn.pixabay.com/photo/2020/02/11/19/43/fruits-4840762_960_720.jpg',
#  'https://cdn.pixabay.com/photo/2020/06/19/21/43/fruit-5318932_960_720.jpg',
#  'https://cdn.pixabay.com/photo/2020/07/01/09/01/fruits-5358938_960_720.png',
#  'https://cdn.pixabay.com/photo/2021/02/23/17/52/fruits-6044263_960_720.jpg',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ1PYGnWrBIKrnp9cl06H4J1Ft5jw2QrNku3g&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQZ9bsfkbQ-2FsX3qWQFK3TFmXX6weiaPge-g&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQZrdGWV1BL7nv1pBKbMshWqrO4U-8oTS5PRQ&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQbiRZ1iXPw_nvSbozqrMtJjPPtsCSfaX21TA&usqp=CAU',
# ...

# %%
search_url = "https://www.google.com/search?q={q}&tbm=isch&tbs=sur%3Afc&hl=en&ved=0CAIQpwVqFwoTCKCa1c6s4-oCFQAAAAAdAAAAABAC&biw=1251&bih=568"
driver.get(search_url.format(q='cars'))

# %%
def scroll_to_end(driver):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)#sleep_between_interactions

# %%
#Locate the images to be scraped from the current page 
imgResults = driver.find_elements_by_xpath("//img[contains(@class,'Q4LuWd')]")
totalResults=len(imgResults)

# %%
img_urls = set()
for i in  range(3,len(imgResults)):
    img=imgResults[i]
    try:
        img.click()
        time.sleep(2)
        actual_images = driver.find_elements_by_css_selector('img.n3VNCb')
        for actual_image in actual_images:
            if actual_image.get_attribute('src') and 'https' in actual_image.get_attribute('src'):
                img_urls.add(actual_image.get_attribute('src'))
    except ElementClickInterceptedException or ElementNotInteractableException as err:
        print(err)

# %%
img_urls
# Out:
# {'https://c0.wallpaperflare.com/preview/279/927/680/car-cars-car-love-carstyle.jpg',
#  'https://c0.wallpaperflare.com/preview/857/830/545/two-white-cars-with-open-hoods.jpg',
#  'https://c1.wallpaperflare.com/preview/110/200/966/urban-car-city-cuba.jpg',
#  'https://c1.wallpaperflare.com/preview/663/122/550/classic-car-car-classic-classic-cars.jpg',
#  'https://c1.wallpaperflare.com/preview/863/535/594/sports-car-pkw-auto-vehicle.jpg',
#  'https://cdn.pixabay.com/photo/2016/03/13/02/50/cuba-1253194_960_720.jpg',
#  'https://cdn.pixabay.com/photo/2019/08/07/15/03/bumper-cars-4390958_960_720.jpg',
#  'https://cdn.pixabay.com/photo/2019/09/25/11/46/cars-4503423_960_720.jpg',
#  'https://cdn.pixabay.com/photo/2021/02/15/02/12/cars-6016373_960_720.jpg',
#  'https://cdn.pixabay.com/photo/2021/03/09/11/47/cars-6081637_960_720.jpg',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ5uVJDLieW4hWTeQAGIt-aBWbeUM3XaLL2fA&usqp=CAU',
# ...

# %%
search_url = "https://www.google.com/search?q={q}&tbm=isch&tbs=sur%3Afc&hl=en&ved=0CAIQpwVqFwoTCKCa1c6s4-oCFQAAAAAdAAAAABAC&biw=1251&bih=568"
driver.get(search_url.format(q='Machine learning'))

# %%
def scroll_to_end(driver):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)#sleep_between_interactions

# %%
#Locate the images to be scraped from the current page 
imgResults = driver.find_elements_by_xpath("//img[contains(@class,'Q4LuWd')]")
totalResults=len(imgResults)

# %%
img_urls = set()
for i in  range(3,len(imgResults)):
    img=imgResults[i]
    try:
        img.click()
        time.sleep(2)
        actual_images = driver.find_elements_by_css_selector('img.n3VNCb')
        for actual_image in actual_images:
            if actual_image.get_attribute('src') and 'https' in actual_image.get_attribute('src'):
                img_urls.add(actual_image.get_attribute('src'))
    except ElementClickInterceptedException or ElementNotInteractableException as err:
        print(err)

# %%
img_urls
# Out:
# {'https://c0.wallpaperflare.com/preview/139/551/691/algorithm-images-by-machine-learn.jpg',
#  'https://c0.wallpaperflare.com/preview/484/290/416/algorithm-images-by-machine-learn.jpg',
#  'https://cdn.pixabay.com/photo/2019/04/15/12/08/machine-learning-4129173_960_720.jpg',
#  'https://cdn.pixabay.com/photo/2019/04/15/12/09/machine-learning-4129175_960_720.jpg',
#  'https://cdn.pixabay.com/photo/2020/07/24/09/25/machine-learning-5433370_960_720.png',
#  'https://cdn.pixabay.com/photo/2020/11/07/10/25/machine-learning-5720531_960_720.png',
#  'https://cdn.pixabay.com/photo/2020/12/05/18/22/machine-learning-5806811_960_720.jpg',
#  'https://cdn.pixabay.com/photo/2021/01/14/17/04/technology-5917397_960_720.png',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNSAsmDKmoQ3Bjq14cU1WZA-GMZXTilmTqMw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQPP4fki7ja1pDi2DXnr1CfjHGsDMUPpn5w0g&usqp=CAU',
# ...

# %% [markdown]
# # PROGRAM - 7

# %%
#connecting to chromedriver

driver = webdriver.Chrome(r'/Users/ankitraj1/chromedriver')

# %%
# accessing the website
# defining the input in the search field

driver.get('https://www.digit.in/')

# %%
 # giving the input in the search field by send_keys
#clicking the search button through .click()


search_button= driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[3]/div[2]/a')
search_button.click()

# %%
user_inp= input('enter the product you want to search:')
# Out:
# enter the product you want to search:top 10 gaming laptops

# %%
# giving the input in the search field by send_keys
#clicking the search button through .click()

search_bar = driver.find_element_by_xpath('//*[@id="globalPageSearchText"]')
search_bar.clear()
search_bar.send_keys(user_inp)
time.sleep(5)

# %%
search_button= driver.find_element_by_xpath('//*[@id="searchgetId"]')
search_button.click()

# %%
# declaring the desired output

title=[]
date=[]

# %%
for j in driver.find_elements_by_xpath('//div[@class="searchProduct-desc"]'):
        title.append(j.text)

# %%
title
# Out:
# ['HP Envy 15-k006tx',
#  "ASUS G53J - A 3D gamer's delight but we want more",
#  'Asus G750JX-CV069P',
#  'ASUS ROG Flow x13',
#  'Lenovo IdeaPad Y570',
#  'ASUS ROG Cetra',
#  'HP Pavilion g6 - Multimedia and gaming on a budget',
#  'MSI Z170A Gaming M7',
#  'ASUS Zephyrus G15 Ryzen 9 5900HS (2021)',
#  'Top gaming laptops under Rs 1 lakh']

# %%
for k in driver.find_elements_by_xpath('/html/body/div[6]/div[2]/div[2]/div[12]/span'):
        date.append(k.text)

# %%
date
# Out:
# ['Apr 09, 2019',
#  'Apr 09, 2019',
#  'Mar 20, 2021',
#  'May 28, 2021',
#  'Apr 09, 2019',
#  'Oct 05, 2020',
#  'Apr 09, 2019',
#  'Sep 03, 2015',
#  'May 28, 2021',
#  'Aug 03, 2017']

# %%
#creating the data frame for the outputs

data = list(zip(title,date))
df = pd.DataFrame (data,columns=['title','date'])

# %%
df.head(10)
# Out:
#                                                title          date
# 0                                  HP Envy 15-k006tx  Apr 09, 2019
# 1  ASUS G53J - A 3D gamer's delight but we want more  Apr 09, 2019
# 2                                 Asus G750JX-CV069P  Mar 20, 2021
# 3                                  ASUS ROG Flow x13  May 28, 2021
# 4                                Lenovo IdeaPad Y570  Apr 09, 2019
# 5                                     ASUS ROG Cetra  Oct 05, 2020
# 6  HP Pavilion g6 - Multimedia and gaming on a bu...  Apr 09, 2019
# 7                                MSI Z170A Gaming M7  Sep 03, 2015
# 8            ASUS Zephyrus G15 Ryzen 9 5900HS (2021)  May 28, 2021
# 9                 Top gaming laptops under Rs 1 lakh  Aug 03, 2017

# %% [markdown]
# # PROGRAM - 4

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def extract_record(url):
    record_req = requests.get(url)
    soup1 = BeautifulSoup(record_req.text,'html.parser')
    
    contents = []
    
    
    try:
        a_string = soup1.find('span',attrs={'class':'B_NuCI'}).text
        Brand = a_string.split()[0].strip()
    except AttributeError:
        return
    
    try:
        discounted_price = soup1.find('div',attrs={'class':'_30jeq3 _16Jk6d'}).text
        discounted_price = discounted_price.replace("₹",'')
    except AttributeError:
        discounted_price = ''
        
    try:
        original_price = soup1.find('div',attrs={'class':'_3I9_wc _2p6lqe'}).text
        original_price = original_price.replace("₹",'')
    except AttributeError:
        original_price = discounted_price
        
    try:
        discount = soup1.find('div',attrs={'class':'_3Ay6Sb _31Dcoz'}).text
    except AttributeError:
        discount =''
     
    try:
        rating =   soup1.find('div',attrs={'class':'_3LWZlK'}).text   
    except AttributeError:
        rating = ''
       
    try:
        rating_count =   soup1.find('span',attrs={'class':'_2_R_DZ'}).text   
    except AttributeError:
        rating_count = ''



    table_count = soup1.find_all('table',attrs={'class':'_14cfVK'})
    for data_table in table_count:
        rows = data_table.find_all('tr')
        for row in rows:
            td = row.find_all('td')
            row1=[i.text.strip() for i in td]
            contents.append(row1)
        
    # Convert the Table contents to Data Frame    
    Mobile_data = pd.DataFrame(contents)

    try:
    #     Mobile_data = pd.DataFrame(contents)
        boolean_finding = len(Mobile_data[Mobile_data[0] == 'Model Name'])
        if boolean_finding:
            test = Mobile_data.loc[Mobile_data[0]== 'Model Name'].index[0]
            ModelName = Mobile_data.loc[test,1]
        else:
            ModelName = ''
            
    except AttributeError:
        ModelName = ''
#     print(ModelName)

    

    # Get Screen type
    try:
    #     Mobile_data = pd.DataFrame(contents)
        boolean_finding = len(Mobile_data[Mobile_data[0] == 'Touchscreen'])
        if boolean_finding:     
            test = Mobile_data.loc[Mobile_data[0]== 'Touchscreen'].index[0]
            Touchscreen = Mobile_data.loc[test,1]
        else:
            Touchscreen =''
                
    except AttributeError:
        Touchscreen = ''
#     print(Touchscreen)

    # Get Display Size 
    try:
    #     Mobile_data = pd.DataFrame(contents)
        boolean_finding = len(Mobile_data[Mobile_data[0] == 'Display Size'])
        if boolean_finding:      
            test = Mobile_data.loc[Mobile_data[0]== 'Display Size'].index[0]
            Displaysize = Mobile_data.loc[test,1]
        else:
            Displaysize = ''
    except AttributeError:
        Displaysize = ''
#     print(Displaysize)

    # Get Primary Camera Available 
    try:
    #     Mobile_data = pd.DataFrame(contents)
        boolean_finding = len(Mobile_data[Mobile_data[0] == 'Primary Camera Available'])
        if boolean_finding:     
            test = Mobile_data.loc[Mobile_data[0]== 'Primary Camera Available'].index[0]
            PCAvailable = Mobile_data.loc[test,1]
        else:
            PCAvailable = ''
    except AttributeError:
        PCAvailable = ''
#     print(PCAvailable)

    # Get Primary Camera info 
    try:
    #     Mobile_data = pd.DataFrame(contents)
        boolean_finding = len(Mobile_data[Mobile_data[0] == 'Primary Camera'])
        if boolean_finding:      
            test = Mobile_data.loc[Mobile_data[0]== 'Primary Camera'].index[0]
            Primarycamera = Mobile_data.loc[test,1]
        else:
            Primarycamera = ''
    except AttributeError:
        Primarycamera = ''
#     print(Primarycamera)


    # Get Secondary Camera Available 
    try:
    #     Mobile_data = pd.DataFrame(contents)
        boolean_finding = len(Mobile_data[Mobile_data[0] == 'Secondary Camera Available'])
        if boolean_finding:      
            test = Mobile_data.loc[Mobile_data[0]== 'Secondary Camera Available'].index[0]
            SCAvailable = Mobile_data.loc[test,1]
        else:
            SCAvailable = ''
    except AttributeError:
        SCAvailable = ''
#     print(SCAvailable)


    # Get Secondary Camera info 
    try:
    #     Mobile_data = pd.DataFrame(contents)
        boolean_finding = len(Mobile_data[Mobile_data[0] == 'Secondary Camera'])
        if boolean_finding:      
            test = Mobile_data.loc[Mobile_data[0]== 'Secondary Camera'].index[0]
            Secondarycamera = Mobile_data.loc[test,1]
        else:
            Secondarycamera = ''
    except AttributeError:
        Secondarycamera = ''
#     print(Secondarycamera)

    # Get Internal Storage 
    try:
    #     Mobile_data = pd.DataFrame(contents)
        boolean_finding = len(Mobile_data[Mobile_data[0] == 'Internal Storage'])
        if boolean_finding:      
            test = Mobile_data.loc[Mobile_data[0]== 'Internal Storage'].index[0]
            Intstorage = Mobile_data.loc[test,1]
        else:
            Intstorage = ''
    except AttributeError:
        Intstorage = ''
#     print(Intstorage)

    # Get RAM Info 
    try:
    #     Mobile_data = pd.DataFrame(contents)
        boolean_finding = len(Mobile_data[Mobile_data[0] == 'RAM'])
        if boolean_finding:      
            test = Mobile_data.loc[Mobile_data[0]== 'RAM'].index[0]
            Ram = Mobile_data.loc[test,1]
        else:
            Ram = ''
    except AttributeError:
        Ram = ''
#     print(Ram)

    # Get Battery Info 
    try:
#         Mobile_data = pd.DataFrame(contents)
        boolean_finding = len(Mobile_data[Mobile_data[0] == 'Battery Capacity'])
        if boolean_finding:  
            test = Mobile_data.loc[Mobile_data[0]== 'Battery Capacity'].index[0]
            Battery = Mobile_data.loc[test,1]
        else:
            Battery = ''
    except AttributeError:
        Battery = ''
#     print(Battery)

   




    result = (Brand,original_price,discounted_price,discount,rating,rating_count,ModelName,Touchscreen,Displaysize,PCAvailable,Primarycamera,SCAvailable,Secondarycamera,Intstorage,Ram,Battery)
    return result

# %%
Brand = []
Original_price = []
Offered_Price = []
Discount = []
Rating = []
Rating_Count = []
Model_Name = []  

Touch_Screen = []
Display_Size = []
PC_Available = []
Primary_Camera = []
SC_Available = []
Secondary_Camera = []
Internal_Storage = []
RAM = []
Battery = []

# No_of_Ratings = []
# No_of_Reviews = []

# %%
baseurl = 'https://www.flipkart.com'

# %%
for x in range(1,41):
    r = requests.get(f'https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&as-pos=1&as-type=RECENT&suggestionId=mobiles%7CMobiles&requestId=87868f22-b3aa-4db5-a84c-c4e55f2d39f3&as-searchtext=mobil&page={x}')
#     soup = BeautifulSoup(r.text,'html.parser')
    soup = BeautifulSoup(r.text,'html.parser')
    productlist = soup.find_all('div',attrs={'class':'_2kHMtA'})
#     print(len(productlist))
    for item in productlist:
        productlinks = []
        for link in item.find_all('a',href=True):
            productlinks.append(baseurl+link['href'])
        for url in productlinks:
            records = []
            record = extract_record(url)
#             print(record)
            if record:
                records.append(record)
                for info in records:
                    brand = info[0]
                    Brand.append(brand)
                    org_price = info[1]
                    Original_price.append(org_price)
                    off_price = info[2]
                    Offered_Price.append(off_price)
                    discount = info[3]
                    Discount.append(discount)
                    rating = info[4]
                    Rating.append(rating)
                    rating_count = info[5]
                    Rating_Count.append(rating_count)
                    ModelName = info[6]
                    Model_Name.append(ModelName)
                    
                    Touchscreen = info[7]
                    Touch_Screen.append(Touchscreen)
                    Displaysize = info[8]
                    Display_Size.append(Displaysize)
                    PCAvailable = info[9]
                    PC_Available.append(PCAvailable)
                    Primarycamera = info[10]
                    Primary_Camera.append(Primarycamera)
                    SCAvailable = info[11]
                    SC_Available.append(SCAvailable)
                    Secondarycamera = info[12]
                    Secondary_Camera.append(Secondarycamera)
                    Intstorage = info[13]
                    Internal_Storage.append(Intstorage)
                    Ram = info[14]
                    RAM.append(Ram)
                   
                    battery = info[15]
                    Battery.append(battery)
            
                
dataset = {'Brand':Brand,'Model_Name':Model_Name,'Original_Price':Original_price,
           'Offered_Price':Offered_Price,'Discount':Discount,'Rating':Rating,'Rating_Count':Rating_Count,
           'Touch_Screen':Touch_Screen,
           'Display_Size':Display_Size,'PCam_Avl':PC_Available,'Primary_Camera':Primary_Camera,
           'SCam_avl':SC_Available,'Secondary_Camera':Secondary_Camera,'Int_Memory':Internal_Storage,
           'RAM':RAM,'Battery':Battery}
data = pd.DataFrame(dataset)
print(len(data.index))
pd.set_option('display.max_colwidth',None)
print(data.head(1))
data.to_csv('Flipkart_Mobiles.csv')
